# %% [markdown]
# # Import libraries

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.87)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)

# %%
# Time Series Forecasting - Multivariate Time Series Models for Stock Market Prediction

import math  
import numpy as np 
import pandas as pd 
from datetime import date, timedelta, datetime 
from pandas.plotting import register_matplotlib_converters 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates 
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Sequential 
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense, Dropout 
from tensorflow.keras.callbacks import EarlyStopping 

from sklearn.metrics import mean_absolute_error, mean_squared_error

from sklearn.preprocessing import RobustScaler, MinMaxScaler 
import seaborn as sns 
sns.set_style('white', { 'axes.spines.right': False, 'axes.spines.top': False})
import yfinance as yf

print('Tensorflow Version: ' + tf.__version__)
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs:", len(physical_devices))
# Out:
# Tensorflow Version: 2.9.2
# Num GPUs: 1

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Preprocessing

# %%
def load(symbol,start_date,end_date):
  df = yf.download(symbol, start=start_date, end=end_date)
  return df

# %%
def count(start_date,end_date):
  end_date_object = datetime.strptime(end_date, '%Y-%m-%d').date()
  start_date_object = datetime.strptime(start_date, '%Y-%m-%d').date()
  return (end_date_object-start_date_object)

# %%
def plot(df):
  df_plot = df.copy()

  num_cols = 2
  num_rows = int(round(df_plot.shape[1] / num_cols, 0))

  fig, ax = plt.subplots(nrows=num_rows, ncols=num_cols, sharex=True, figsize=(20, 10))
  for i, ax in enumerate(fig.axes):
          sns.lineplot(data = df_plot.iloc[:, i], ax=ax)
          ax.tick_params(axis="x", rotation=30, labelsize=15, length=0)
          ax.xaxis.set_major_locator(mdates.AutoDateLocator())
  fig.tight_layout()
  plt.show()

# %%
def preprocess(df, seq_len, split=0.8):
  sequence_length = seq_len

  stock_features = ['High', 'Low', 'Open', 'Close', 'Volume']

  train_df = df.sort_values(by=['Date']).copy()

  data = pd.DataFrame(train_df)
  data_filtered = data[stock_features]

  data_filtered_ext = data_filtered.copy()
  data_filtered_ext['Prediction'] = data_filtered_ext['Close']

  data_filtered_ext.tail()

  nrows = data_filtered.shape[0]

  np_data_unscaled = np.array(data_filtered)
  np_data = np.reshape(np_data_unscaled, (nrows, -1))
  print(np_data.shape)

  scaler = MinMaxScaler()
  np_data_scaled = scaler.fit_transform(np_data_unscaled)

  scaler_pred = MinMaxScaler()
  df_Close = pd.DataFrame(data_filtered_ext['Close'])
  np_Close_scaled = scaler_pred.fit_transform(df_Close)

  index_Close = data.columns.get_loc("Close")

  train_data_len = math.ceil(np_data_scaled.shape[0] * split)

  train_data = np_data_scaled[0:train_data_len, :]
  val_data = np_data_scaled[train_data_len - sequence_length:, :]

  def partition_rnn(sequence_length, data):
      x, y = [], []
      data_len = data.shape[0]
      for i in range(sequence_length, data_len):
          x.append(data[i-sequence_length:i,:])
          y.append(data[i, index_Close]) 
      
      x = np.array(x)
      y = np.array(y)
      return x, y

  x_train, y_train = partition_rnn(sequence_length, train_data)
  x_val, y_val = partition_rnn(sequence_length, val_data)

  return stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_val, y_val

# %% [markdown]
# # Build RNN model

# %%
def create_RNN(hidden_units, input_shape, rnn_type, lr, loss, drop=0.2):
  model = Sequential()
  if rnn_type == 'RNN':

    model.add(SimpleRNN(hidden_units, return_sequences=True, input_shape=input_shape)) 
    model.add(Dropout(drop))
    model.add(SimpleRNN(hidden_units, return_sequences=True))
    model.add(SimpleRNN(hidden_units, return_sequences=False))

  elif rnn_type == 'LSTM':

    model.add(LSTM(hidden_units, return_sequences=True, input_shape=input_shape)) 
    model.add(Dropout(drop))
    model.add(LSTM(hidden_units, return_sequences=True))
    model.add(LSTM(hidden_units, return_sequences=False))

  elif rnn_type == 'GRU':

    model.add(GRU(hidden_units, return_sequences=True, input_shape=input_shape)) 
    model.add(Dropout(drop))
    model.add(GRU(hidden_units, return_sequences=True))
    model.add(GRU(hidden_units, return_sequences=False))

  model.add(Dense(1))

  opt = keras.optimizers.Adam(learning_rate=lr)
  model.compile(optimizer=opt, loss=loss)

  return model

# %%
def loss_plot(history, epochs, rnn_type ="Vanilla RNN"):
  fig, ax = plt.subplots(figsize=(12, 5), sharex=True)
  sns.lineplot(data=history.history["loss"])
  sns.lineplot(data=history.history["val_loss"])
  plt.title(f"Loss Curve w/ {rnn_type}")
  plt.ylabel("Loss")
  plt.xlabel("Steps")
  plt.legend(["Train", "Val"], loc="upper left")
  plt.grid()
  plt.show()

# %%
def evaluate(model, x_train, y_train, x_val, y_val, scaler_pred, epoch, batch_size): #SimpleRNN_model | LSTM_model | GRU_model
  epochs = epoch
  batch_size = batch_size
  early_stop = EarlyStopping(monitor='loss', patience=5, verbose=1)
  history = model.fit(x_train, y_train, 
                      batch_size=batch_size, 
                      epochs=epochs,
                      validation_data=(x_val, y_val)
                      #,callbacks=[early_stop])
                    )
                    
  y_pred_scaled = model.predict(x_val)
  y_pred = scaler_pred.inverse_transform(y_pred_scaled)
  y_val_unscaled = scaler_pred.inverse_transform(y_val.reshape(-1, 1))

  MAE = mean_absolute_error(y_val_unscaled, y_pred)
  MAPE = np.mean((np.abs(np.subtract(y_val_unscaled, y_pred)/ y_val_unscaled))) * 100
  MDAPE = np.median((np.abs(np.subtract(y_val_unscaled, y_pred)/ y_val_unscaled)) ) * 100

  return history, y_pred, MAE, MAPE, MDAPE

# %%
def evaluate_plot(data_filtered_ext, train_data_len, y_pred, stockname, display_start_date = "2019-01-01", rnn_type="LSTM" ):
  train = pd.DataFrame(data_filtered_ext['Close'][:train_data_len + 1]).rename(columns={'Close': 'y_train'})
  val = pd.DataFrame(data_filtered_ext['Close'][train_data_len:]).rename(columns={'Close': 'y_val'})
  val.insert(1, "y_pred", y_pred, True)
  df_union = pd.concat([val, train])

  df_union_zoom = df_union[df_union.index > display_start_date]

  fig, ax1 = plt.subplots(figsize=(12, 5))
  plt.title(f"Stock Price Prediction w/ {rnn_type}")
  plt.ylabel(stockname)
  sns.lineplot(data=df_union_zoom[['y_train',  'y_val', 'y_pred']], linewidth=1.0, dashes=False, ax=ax1)
  plt.legend()
  plt.grid()
  plt.show()

# %% [markdown]
# # Stock company

# %%
symbol ='BKNG'
stock_company = 'Booking Holdings Inc'

start_date = '2018-01-01'
end_date =  date.today().strftime("%Y-%m-%d")

df = load(symbol,start_date, end_date)
print(df.head())

print(count(start_date, end_date))

plot(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  1750.089966  1790.660034  1744.500000  1784.750000  1784.750000
# 2018-01-03  1790.229980  1829.020020  1785.000000  1824.160034  1824.160034
# 2018-01-04  1838.540039  1848.900024  1802.030029  1807.250000  1807.250000
# 2018-01-05  1820.180054  1825.500000  1805.800049  1823.540039  1823.540039
# 2018-01-08  1827.489990  1874.949951  1825.189941  1851.810059  1851.810059
#
#             Volume
# Date
# 2018-01-02  475500
# 2018-01-03  525000
# 2018-01-04  592600
# 2018-01-05  358600
# 2018-01-08  555600
# 1784 days, 0:00:00

# %% [markdown]
# # RNN

# %%
sequence_length = 50 #sliding_window 
stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_val, y_val = preprocess(df, seq_len = sequence_length)

h0 = x_train.shape[1] * x_train.shape[2]
# Out:
# (1231, 5)

# %%
epoch=50
batch_size=32
lr=0.001
loss="mean_squared_error"


SimpleRNN_model = create_RNN(hidden_units = h0, input_shape=(x_train.shape[1], x_train.shape[2]), rnn_type='RNN', lr=lr, loss=loss)

history, y_pred_simplernn, MAE_simplernn, MAPE_simplernn, MDAPE_simplernn = evaluate(SimpleRNN_model, x_train, y_train, x_val, y_val, scaler_pred, epoch=epoch, batch_size=batch_size)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 14s 261ms/step - loss: 0.8668 - val_loss: 0.0377
# Epoch 2/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0300 - val_loss: 0.0321
# Epoch 3/50
# 30/30 [==============================] - 3s 116ms/step - loss: 0.0664 - val_loss: 2.3400
# Epoch 4/50
# 30/30 [==============================] - 4s 129ms/step - loss: 2.2690 - val_loss: 0.0505
# Epoch 5/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0599 - val_loss: 0.0352
# Epoch 6/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0413 - val_loss: 0.0253
# Epoch 7/50
# 30/30 [==============================] - 3s 114ms/step - loss: 0.0351 - val_loss: 0.0245
# Epoch 8/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0372 - val_loss: 0.0327
# Epoch 9/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0296 - val_loss: 0.0203
# Epoch 10/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0239 - val_loss: 0.0178
# Epoch 11/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0286 - val_loss: 0.0251
# Epoch 12/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0280 - val_loss: 0.0207
# Epoch 13/50
# 30/30 [==============================] - 3s 113ms/step - loss: 0.0247 - val_loss: 0.0560
# Epoch 14/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0261 - val_loss: 0.0217
# Epoch 15/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.0221 - val_loss: 0.0182
# Epoch 16/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0221 - val_loss: 0.0264
# Epoch 17/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0234 - val_loss: 0.0179
# Epoch 18/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0236 - val_loss: 0.0499
# Epoch 19/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0297 - val_loss: 0.0297
# Epoch 20/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0221 - val_loss: 0.0492
# Epoch 21/50
# 30/30 [==============================] - 4s 144ms/step - loss: 0.0268 - val_loss: 0.0147
# Epoch 22/50
# 30/30 [==============================] - 3s 114ms/step - loss: 0.0204 - val_loss: 0.0311
# Epoch 23/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0225 - val_loss: 0.0464
# Epoch 24/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0190 - val_loss: 0.0142
# Epoch 25/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0163 - val_loss: 0.0136
# Epoch 26/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0181 - val_loss: 0.0318
# Epoch 27/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0238 - val_loss: 0.0174
# Epoch 28/50
# 30/30 [==============================] - 3s 115ms/step - loss: 0.0170 - val_loss: 0.0319
# Epoch 29/50
# 30/30 [==============================] - 4s 148ms/step - loss: 0.0214 - val_loss: 0.0155
# Epoch 30/50
# 30/30 [==============================] - 9s 287ms/step - loss: 0.0148 - val_loss: 0.0220
# Epoch 31/50
# 30/30 [==============================] - 3s 114ms/step - loss: 0.0197 - val_loss: 0.0164
# Epoch 32/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0163 - val_loss: 0.0117
# Epoch 33/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0168 - val_loss: 0.0125
# Epoch 34/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.0146 - val_loss: 0.0179
# Epoch 35/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0152 - val_loss: 0.0161
# Epoch 36/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0130 - val_loss: 0.0090
# Epoch 37/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0115 - val_loss: 0.0131
# Epoch 38/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0116 - val_loss: 0.0061
# Epoch 39/50
# 30/30 [==============================] - 3s 114ms/step - loss: 0.0136 - val_loss: 0.0115
# Epoch 40/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0123 - val_loss: 0.0052
# Epoch 41/50
# 30/30 [==============================] - 3s 114ms/step - loss: 0.0117 - val_loss: 0.0082
# Epoch 42/50
# 30/30 [==============================] - 4s 149ms/step - loss: 0.0087 - val_loss: 0.0160
# Epoch 43/50
# 30/30 [==============================] - 3s 110ms/step - loss: 0.0128 - val_loss: 0.0071
# Epoch 44/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 45/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0080 - val_loss: 0.0171
# Epoch 46/50
# 30/30 [==============================] - 3s 112ms/step - loss: 0.0076 - val_loss: 0.0031
# Epoch 47/50
# 30/30 [==============================] - 3s 111ms/step - loss: 0.0080 - val_loss: 0.0035
# Epoch 48/50
# 30/30 [==============================] - 3s 113ms/step - loss: 0.0062 - val_loss: 0.0048
# Epoch 49/50
# 30/30 [==============================] - 3s 113ms/step - loss: 0.0058 - val_loss: 0.0070
# Epoch 50/50
# 30/30 [==============================] - 4s 127ms/step - loss: 0.0087 - val_loss: 0.0040
# 8/8 [==============================] - 0s 12ms/step

# %%
SimpleRNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50, 250)           64000
#
#  dropout (Dropout)           (None, 50, 250)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 50, 250)           125250
#
#  simple_rnn_2 (SimpleRNN)    (None, 250)               125250
#
#  dense (Dense)               (None, 1)                 251
#
# =================================================================
# Total params: 314,751
# Trainable params: 314,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
print( MAE_simplernn, MAPE_simplernn, MDAPE_simplernn)
# Out:
# 79.20114110931148 3.8917502528867205 3.426033327640117

# %%
loss_plot(history, epochs=epoch, rnn_type ="Vanilla RNN")

# %%
evaluate_plot(data_filtered_ext, train_data_len, y_pred_simplernn, stock_company, display_start_date = start_date, rnn_type ="Vanilla RNN")

# %% [markdown]
# # LSTM

# %%
sequence_length = 50 #sliding_window 
stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_test, y_test = preprocess(df, seq_len = sequence_length)
h0 = x_train.shape[1] * x_train.shape[2]
# Out:
# (1231, 5)

# %%
epoch=50
batch_size=32
lr=0.001
loss="mean_squared_error"
LSTM_model = create_RNN(hidden_units = h0, input_shape=(x_train.shape[1], x_train.shape[2]), rnn_type='LSTM',lr=lr, loss=loss)
history, y_pred_LSTM, MAE_LSTM, MAPE_LSTM, MDAPE_LSTM = evaluate(LSTM_model, x_train, y_train, x_test, y_test, scaler_pred, epoch=epoch, batch_size=batch_size)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 11s 88ms/step - loss: 0.0177 - val_loss: 0.0084
# Epoch 2/50
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0038 - val_loss: 0.0080
# Epoch 3/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0033 - val_loss: 0.0065
# Epoch 4/50
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0029 - val_loss: 0.0071
# Epoch 5/50
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0025 - val_loss: 0.0052
# Epoch 6/50
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0025 - val_loss: 0.0047
# Epoch 7/50
# 30/30 [==============================] - 1s 25ms/step - loss: 0.0025 - val_loss: 0.0045
# Epoch 8/50
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 9/50
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0025 - val_loss: 0.0046
# Epoch 10/50
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 11/50
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 12/50
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 13/50
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 14/50
# 30/30 [==============================] - 1s 26ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 15/50
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 16/50
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 17/50
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 18/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 19/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 20/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0016 - val_loss: 0.0057
# Epoch 21/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 22/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 23/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 24/50
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 25/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 26/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 27/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 28/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 29/50
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 30/50
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 31/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 32/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0027
# Epoch 33/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 34/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 35/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 36/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 37/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 38/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 39/50
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 40/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 41/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 42/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 43/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 44/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 45/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 46/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 47/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 48/50
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 49/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 50/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0021
# 8/8 [==============================] - 1s 6ms/step

# %%
loss_plot(history, epochs=epoch, rnn_type ="LSTM")

# %%
print(MAE_LSTM, MAPE_LSTM, MDAPE_LSTM)
# Out:
# 57.22547726514863 2.701386485619376 2.393350772449087

# %%
evaluate_plot(data_filtered_ext, train_data_len, y_pred_LSTM, stock_company, display_start_date = start_date, rnn_type ="LSTM")

# %% [markdown]
# # GRU

# %%
sequence_length = 50 #sliding_window 
stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_val, y_val = preprocess(df, seq_len = sequence_length)

h0 = x_train.shape[1] * x_train.shape[2]
# Out:
# (1231, 5)

# %%
epoch=50
batch_size=32
lr=0.001
loss="mean_squared_error"

GRU_model = create_RNN(hidden_units = h0, input_shape=(x_train.shape[1], x_train.shape[2]),  rnn_type='GRU',lr=lr, loss=loss)
history, y_pred_GRU, MAE_GRU, MAPE_GRU, MDAPE__GRU = evaluate(GRU_model, x_train, y_train, x_val, y_val, scaler_pred, epoch=epoch, batch_size=batch_size)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 7s 48ms/step - loss: 0.0166 - val_loss: 0.0039
# Epoch 2/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 3/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 4/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 5/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 6/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 7/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 8/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 9/50
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 10/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 11/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 12/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 13/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 14/50
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 15/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 16/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 17/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 18/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 19/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 20/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 21/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 22/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 23/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.9613e-04 - val_loss: 0.0017
# Epoch 24/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.9420e-04 - val_loss: 0.0016
# Epoch 25/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 26/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 27/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.8794e-04 - val_loss: 0.0018
# Epoch 28/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 29/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 30/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 31/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 32/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.4291e-04 - val_loss: 0.0021
# Epoch 33/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 34/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.9838e-04 - val_loss: 0.0020
# Epoch 35/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 36/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.5308e-04 - val_loss: 0.0015
# Epoch 37/50
# 30/30 [==============================] - 0s 14ms/step - loss: 9.7133e-04 - val_loss: 0.0015
# Epoch 38/50
# 30/30 [==============================] - 0s 14ms/step - loss: 9.4631e-04 - val_loss: 0.0021
# Epoch 39/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.3040e-04 - val_loss: 0.0015
# Epoch 40/50
# 30/30 [==============================] - 0s 14ms/step - loss: 8.8274e-04 - val_loss: 0.0020
# Epoch 41/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 42/50
# 30/30 [==============================] - 0s 15ms/step - loss: 8.8649e-04 - val_loss: 0.0017
# Epoch 43/50
# 30/30 [==============================] - 0s 15ms/step - loss: 8.9965e-04 - val_loss: 0.0015
# Epoch 44/50
# 30/30 [==============================] - 0s 14ms/step - loss: 9.1650e-04 - val_loss: 0.0018
# Epoch 45/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 46/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 47/50
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 48/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.8426e-04 - val_loss: 0.0016
# Epoch 49/50
# 30/30 [==============================] - 0s 13ms/step - loss: 9.2428e-04 - val_loss: 0.0015
# Epoch 50/50
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0017
# 8/8 [==============================] - 1s 8ms/step

# %%
loss_plot(history, epochs=epoch, rnn_type ="GRU")

# %%
print(MAE_GRU, MAPE_GRU, MDAPE__GRU)
# Out:
# 51.94777425130209 2.4658272001661734 2.1494518341103865

# %%
evaluate_plot(data_filtered_ext, train_data_len, y_pred_GRU, stock_company, display_start_date = start_date, rnn_type ="GRU")

# %%
fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(data=y_pred_simplernn)
sns.lineplot(data=y_pred_LSTM, palette="Set1")
sns.lineplot(data=y_pred_GRU,  palette="Set2")
plt.title("Comparion on stock prediction models")
plt.ylabel("y_pred")
plt.xlabel("Epoch")
plt.legend(["RNN", "LSTM", "GRU"], loc="upper left")
plt.grid()
plt.show()

# %% [markdown]
# # Predict Next Day

# %%
df_temp = df[-sequence_length:]
new_df = df_temp.filter(stock_features)

N = sequence_length

last_N_days = new_df[-sequence_length:].values
last_N_days_scaled = scaler.transform(last_N_days)

X_test_new = []
X_test_new.append(last_N_days_scaled)

pred_price_scaled = LSTM_model.predict(np.array(X_test_new)) #try best model
pred_price_unscaled = scaler_pred.inverse_transform(pred_price_scaled.reshape(-1, 1))

now_price = np.round(new_df['Close'][-1], 2)
predicted_price = np.round(pred_price_unscaled.ravel()[0], 2)
delta = np.round(100 - (now_price * 100)/predicted_price, 2)
print(end_date)
print('predicted price: ', predicted_price)
print('actual price: ', now_price)
print('delta: ', delta, '%')
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 2022-11-20
# predicted price:  1906.48
# actual price:  1940.28
# delta:  -1.77 %
